# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
d1=df.dropna(inplace=True)

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
summary = iris.groupby('species').agg({'sepal_length': 'mean', 'sepal_width': 'mean', 'petal_length': 'mean', 'petal_width': 'mean', 'species': 'count'})

# %%
summary.columns = ['Mean Sepal Length', 'Mean Sepal Width', 'Mean Petal Length', 'Mean Petal Width', 'Count']

# %%
summary.columns = ['Mean Sepal Length', 'Mean Sepal Width', 'Mean Petal Length', 'Mean Petal Width', 'Count']

# %%
summary
# Out:
#             Mean Sepal Length  Mean Sepal Width  Mean Petal Length  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             Mean Petal Width  Count
# species
# setosa                 0.246     50
# versicolor             1.326     50
# virginica              2.026     50

# %%
summary.columns
# Out:
# Index(['Mean Sepal Length', 'Mean Sepal Width', 'Mean Petal Length',
#        'Mean Petal Width', 'Count'],
#       dtype='object')

# %%
pivot_table=pd.pivot_table(df,values='SepalLengthCm',index='PetalLengthCm',columns='Species')
pivot_table
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# PetalLengthCm
# 1.0               4.600000              NaN             NaN
# 1.1               4.300000              NaN             NaN
# 1.2               5.400000              NaN             NaN
# 1.3               4.842857              NaN             NaN
# 1.4               4.916667              NaN             NaN
# 1.5               5.128571              NaN             NaN
# 1.6               4.914286              NaN             NaN
# 1.7               5.400000              NaN             NaN
# 1.9               4.950000              NaN             NaN
# 3.0                    NaN         5.100000             NaN
# 3.3                    NaN         4.950000             NaN
# 3.5                    NaN         5.350000             NaN
# 3.6                    NaN         5.600000             NaN
# 3.7                    NaN         5.500000             NaN
# ...

# %%
import pandas as pd

# Sample dataset
data = {
    'Date': ['2023-09-01', '2023-09-01', '2023-09-02', '2023-09-02', '2023-09-03'],
    'Product': ['A', 'B', 'A', 'B', 'A'],
    'Sales': [100, 150, 120, 200, 80]
}

df = pd.DataFrame(data)

# Create a pivot table to summarize data
pivot_table = pd.pivot_table(df, values='Sales', index='Date', columns='Product', aggfunc='sum')

# Display the pivot table
print(pivot_table)
# Out:
# Product         A      B
# Date
# 2023-09-01  100.0  150.0
# 2023-09-02  120.0  200.0
# 2023-09-03   80.0    NaN
