# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Education.csv')
df.head(5)
# Out:
#    Sr.no                                     Institute Name       State  \
# 0      1                    MANIPUR INSTITUTE OF TECHNOLOGY     Manipur
# 1      2  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
# 2      3  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
# 3      4  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
# 4      5  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
#
#       District                    Type      Affiliating University  \
# 0  IMPHAL WEST              Government  Manipur University, Imphal
# 1   COIMBATORE  Private-Self Financing    Anna University, Chennai
# 2   COIMBATORE  Private-Self Financing    Anna University, Chennai
# 3   COIMBATORE  Private-Self Financing    Anna University, Chennai
# 4   COIMBATORE  Private-Self Financing    Anna University, Chennai
#
#                       Program           Level  \
# 0  ENGINEERING AND TECHNOLOGY  UNDER GRADUATE
# ...

# %%
df.isna().sum()
# Out:
# Sr.no                      0
# Institute Name             0
# State                      0
# District                   0
# Type                       0
# Affiliating University    57
# Program                    0
# Level                      0
# Course                     0
# Accreditation Till         0
# Intake                     0
# dtype: int64

# %%
df.describe()
# Out:
#              Sr.no       Intake
# count  2338.000000  2338.000000
# mean   1169.500000   105.605218
# std     675.066787    72.490238
# min       1.000000     9.000000
# 25%     585.250000    60.000000
# 50%    1169.500000   100.000000
# 75%    1753.750000   120.000000
# max    2338.000000  1500.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2338 entries, 0 to 2337
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sr.no                   2338 non-null   int64
#  1   Institute Name          2338 non-null   object
#  2   State                   2338 non-null   object
#  3   District                2338 non-null   object
#  4   Type                    2338 non-null   object
#  5   Affiliating University  2338 non-null   object
#  6   Program                 2338 non-null   object
#  7   Level                   2338 non-null   object
#  8   Course                  2338 non-null   object
#  9   Accreditation Till      2338 non-null   object
#  10  Intake                  2338 non-null   int64
# dtypes: int64(2), object(9)
# memory usage: 201.1+ KB

# %%
df.isna().sum()
# Out:
# Sr.no                     0
# Institute Name            0
# State                     0
# District                  0
# Type                      0
# Affiliating University    0
# Program                   0
# Level                     0
# Course                    0
# Accreditation Till        0
# Intake                    0
# dtype: int64

# %%
df.head()
# Out:
#    Sr.no                                     Institute Name       State  \
# 0      1                    MANIPUR INSTITUTE OF TECHNOLOGY     Manipur
# 1      2  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
# 2      3  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
# 3      4  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
# 4      5  DR MAHALINGAM COLLEGE OF ENGINEERING AND TECHN...  Tamil Nadu
#
#       District                    Type Affiliating University  \
# 0  IMPHAL WEST              Government                Unknown
# 1   COIMBATORE  Private-Self Financing                Unknown
# 2   COIMBATORE  Private-Self Financing                Unknown
# 3   COIMBATORE  Private-Self Financing                Unknown
# 4   COIMBATORE  Private-Self Financing                Unknown
#
#                       Program           Level  \
# 0  ENGINEERING AND TECHNOLOGY  UNDER GRADUATE
# 1  ENGINEERING AND TECHNOLOGY  UNDER GRADUATE
# ...

# %%
df.shape
# Out:
# (2338, 11)

# %%
df.to_csv('cleaned_data.csv', index=False)
